# %% [markdown]
# Exploration des nouvelles données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from itables import show

# %%
#load data_releve_nb_dechet.csv
data_releve_nb_dechet = pd.read_csv("data/processed_data/data_releve_nb_dechet.csv")
show(data_releve_nb_dechet)
# Out:
# <div class="itables">
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables { font-size: medium; }
#
# .itables select, .itables input {
#     color: inherit;
# }
# </style>
# <table id="itables_2eccbd4a_ad73_454d_830e_4083f817299a" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>ID_RELEVE</th>
#       <th>type_regroupement</th>
#       <th>categorie</th>
#       <th>nb_dechet</th>
#     </tr>
# ...

# %%
#load data_releve_nb_dechet.csv
data_releve_nb_dechet = pd.read_csv("data/processed_data/data_zds_enriched.csv")

# %%
show(data_releve_nb_dechet)
# Out:
# <div class="itables">
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables { font-size: medium; }
#
# .itables select, .itables input {
#     color: inherit;
# }
# </style>
# <table id="itables_5a111185_671a_4ecb_81cf_3d1d05e7ab49" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>ID_RELEVE</th>
#       <th>LIEU_PAYS</th>
#       <th>LIEU_REGION</th>
#       <th>LIEU_DEPT</th>
#       <th>LIEU_VILLE</th>
#       <th>LIEU_CODE_POSTAL</th>
#       <th>LIEU_COORD_GPS</th>
#       <th>LIEU_COORD_GPS_X</th>
# ...

# %%
show(data_releve_nb_dechet.isna().sum())
# Out:
# <div class="itables">
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables { font-size: medium; }
#
# .itables select, .itables input {
#     color: inherit;
# }
# </style>
# <table id="itables_b4a35c23_c296_4fcd_b869_2820cafcb631" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# ...
