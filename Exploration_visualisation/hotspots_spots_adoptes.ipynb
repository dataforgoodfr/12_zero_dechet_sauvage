# %% [markdown]
# # Hotspots "spots adoptés" notebook

# %% [markdown]
# The goal of this notebook is to construct a function that return a map of adopted spot by regions, with a filter by environment.

# %%
import pandas as pd
pd.set_option("display.max_rows", None)

import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import folium
from shapely.geometry import Point
from folium import plugins
from folium.plugins import MarkerCluster
from branca.colormap import LinearColormap

# %%
# Global variables
# csv path
DATA_PATH = 'https://github.com/dataforgoodfr/12_zero_dechet_sauvage/raw/2-nettoyage-et-augmentation-des-donn%C3%A9es/Exploration_visualisation/data/data_zds_enriched.csv'

# Place other global variables here
FRANCE_REGIONS = "regions-avec-outre-mer.geojson"

# %%
# Load the enriched dataset
data_zds = pd.read_csv(DATA_PATH)

# Display col names
display(pd.DataFrame({"columns": data_zds.columns}))
# Out:
#                                columns
# 0                            ID_RELEVE
# 1                            LIEU_PAYS
# 2                          LIEU_REGION
# 3                            LIEU_DEPT
# 4                           LIEU_VILLE
# 5                     LIEU_CODE_POSTAL
# 6                       LIEU_COORD_GPS
# 7                     LIEU_COORD_GPS_X
# 8                     LIEU_COORD_GPS_Y
# 9                             NOM_ZONE
# 10                            SPOT_A1S
# 11                             SPOT_ID
# 12                           TYPE_LIEU
# 13                         TYPE_MILIEU
# 14                          TYPE_LIEU2
# 15                         TYPE_DECHET
# 16                   LONGUEUR_LINEAIRE
# 17                             SURFACE
# 18                        ID_EVENEMENT
# 19                       NOM_EVENEMENT
# 20                      TYPE_EVENEMENT
# 21                 EVENEMENT_ENVERGURE
# 22                                DATE
# 23                               ANNEE
# 24                       NOM_STRUCTURE
# 25                        ID_STRUCTURE
# 26                     NB_PARTICIPANTS
# 27                               DUREE
# 28                        NIVEAU_CARAC
# 29                   VERSION_PROTOCOLE
# 30                        VOLUME_TOTAL
# 31                   VOLUME_TOTAL_SACS
# 32                         POIDS_TOTAL
# 33                   VOLUME_VOLUMINEUX
# 34              POURCENTAGE_VOLUMINEUX
# 35            GLOBAL_POURCENTAGE_TOTAL
# 36        GLOBAL_POURCENTAGE_PLASTIQUE
# 37       GLOBAL_POURCENTAGE_CAOUTCHOUC
# 38             GLOBAL_POURCENTAGE_BOIS
# 39          GLOBAL_POURCENTAGE_TEXTILE
# 40           GLOBAL_POURCENTAGE_PAPIER
# 41            GLOBAL_POURCENTAGE_METAL
# 42            GLOBAL_POURCENTAGE_VERRE
# 43            GLOBAL_POURCENTAGE_AUTRE
# 44             GLOBAL_VOLUME_PLASTIQUE
# 45            GLOBAL_VOLUME_CAOUTCHOUC
# 46                  GLOBAL_VOLUME_BOIS
# 47               GLOBAL_VOLUME_TEXTILE
# 48                GLOBAL_VOLUME_PAPIER
# 49                 GLOBAL_VOLUME_METAL
# 50                 GLOBAL_VOLUME_VERRE
# 51                 GLOBAL_VOLUME_AUTRE
# 52          SACS_POURCENTAGE_PLASTIQUE
# 53         SACS_POURCENTAGE_CAOUTCHOUC
# 54               SACS_POURCENTAGE_BOIS
# 55            SACS_POURCENTAGE_TEXTILE
# 56             SACS_POURCENTAGE_PAPIER
# 57              SACS_POURCENTAGE_METAL
# 58              SACS_POURCENTAGE_VERRE
# 59              SACS_POURCENTAGE_AUTRE
# 60               SACS_VOLUME_PLASTIQUE
# 61              SACS_VOLUME_CAOUTCHOUC
# 62                    SACS_VOLUME_BOIS
# 63                 SACS_VOLUME_TEXTILE
# 64                  SACS_VOLUME_PAPIER
# 65                   SACS_VOLUME_METAL
# 66                   SACS_VOLUME_VERRE
# 67                   SACS_VOLUME_AUTRE
# 68                SACS_POIDS_PLASTIQUE
# 69               SACS_POIDS_CAOUTCHOUC
# 70                     SACS_POIDS_BOIS
# 71                  SACS_POIDS_TEXTILE
# 72                   SACS_POIDS_PAPIER
# 73                    SACS_POIDS_METAL
# 74                    SACS_POIDS_VERRE
# 75                    SACS_POIDS_AUTRE
# 76    VOLUMINEUX_POURCENTAGE_PLASTIQUE
# 77   VOLUMINEUX_POURCENTAGE_CAOUTCHOUC
# 78         VOLUMINEUX_POURCENTAGE_BOIS
# 79      VOLUMINEUX_POURCENTAGE_TEXTILE
# 80       VOLUMINEUX_POURCENTAGE_PAPIER
# 81        VOLUMINEUX_POURCENTAGE_METAL
# 82        VOLUMINEUX_POURCENTAGE_VERRE
# 83        VOLUMINEUX_POURCENTAGE_AUTRE
# 84         VOLUMINEUX_VOLUME_PLASTIQUE
# 85        VOLUMINEUX_VOLUME_CAOUTCHOUC
# 86              VOLUMINEUX_VOLUME_BOIS
# 87           VOLUMINEUX_VOLUME_TEXTILE
# 88            VOLUMINEUX_VOLUME_PAPIER
# 89             VOLUMINEUX_VOLUME_METAL
# 90             VOLUMINEUX_VOLUME_VERRE
# 91             VOLUMINEUX_VOLUME_AUTRE
# 92              COMMENTAIRE_VOLUMINEUX
# 93                      AUTRES_DECHETS
# 94                   NB_DECHETS_AUTRES
# 95                         COMMENTAIRE
# 96                             commune
# 97                           INSEE_COM
# 98                                 DEP
# 99                                 REG
# 100                               EPCI
# 101                        NATURE_EPCI
# 102                             BV2022
# 103                            LIBEPCI
# 104                        DEPARTEMENT
# 105                             REGION
# 106                      BASSIN_DE_VIE

# %%
# Display the column "type de milieu"
data_zds["REGION"].unique()
# Out:
# array(["Provence-Alpes-Côte d'Azur", 'Occitanie', 'Normandie',
#        'Auvergne-Rhône-Alpes', 'Île-de-France', 'Nouvelle-Aquitaine',
#        'Bretagne', 'Corse', 'Bourgogne-Franche-Comté',
#        'Centre-Val de Loire', 'Pays de la Loire', 'Grand Est',
#        'Hauts-de-France'], dtype=object)

# %%
# Create the function(s) for scalable filtering
def construct_query_string(bound_word = " and ",
                           **params
                           ) -> str:
    """Construct a query string in the right format for the pandas 'query'
    function. The different params are bounded together in the query string with the
    bound word given by default. If one of the params is 'None', it is not
    included in the final query string."""

    # Instanciate query string
    query_string = ""

    # Iterate over the params to construct the query string
    for param_key, param in params.items():
        # Construct the param sub string if the param is not 'None'
        if param:
            query_sub_string = f"{param_key} == '{param}'"

            # Add to the query string
            query_string += f"{query_sub_string}{bound_word}"

    # Strip any remaining " and " at the end of the query string
    return query_string.strip(bound_word)

# %%
# Construct the adopted waste spots function
def plot_adopted_waste_spots(data_zds: pd.DataFrame,
                             filter_dict: dict,
                             region_geojson = FRANCE_REGIONS,
                             ) -> folium.Map:
    """Show a folium innteractive map of adopted spots within a selected region,
    filtered by environments of deposit.
    Arguments:
    - data_zds: The waste dataframe
    - filter_dict: dictionary mapping the name of the column in the waste df and the value you want to filter by
    """
    ####################################
    # 1/ Create the waste geodataframe #
    ####################################

    # Create a GeoDataFrame for waste points
    gdf = gpd.GeoDataFrame(
        data_zds,
        geometry = gpd.points_from_xy(data_zds["LIEU_COORD_GPS_X"], data_zds["LIEU_COORD_GPS_Y"]),
        crs = "EPSG:4326"
    )

    # Construct the query string
    query_string = construct_query_string(**filter_dict)

    # Filter the geodataframe by region and by environment
    gdf_filtered = gdf.query(query_string)

    ######################################
    # 2/ Create the regions geodataframe #
    ######################################

    # Unpack the region name
    region = filter_dict["REGION"]

    # Load France regions from a GeoJSON file
    regions = gpd.read_file(region_geojson)
    regions = regions.loc[regions["nom"] == region, :]

    # Filter the region geodataframe for the specified region
    selected_region = regions[regions["nom"].str.lower() == region.lower()]
    if selected_region.empty:
        raise KeyError(f"Region '{region}' not found.")

    ############################
    # 3/ Initialize folium map #
    ############################

    # Initialize a folium map, centered around the mean location of the waste points
    map_center = [gdf_filtered.geometry.y.mean(), gdf_filtered.geometry.x.mean()]
    m = folium.Map(location = map_center, zoom_start = 5)  # Adjust zoom_start as needed for the best initial view

    ######################
    # 4/ Add the markers #
    ######################

    # Use MarkerCluster to manage markers if dealing with a large number of points
    marker_cluster = MarkerCluster().add_to(m)

    # Add each waste point as a marker on the folium map
    for _, row in gdf_filtered.iterrows():
        # Define the marker color: green for adopted spots, red for others
        marker_color = 'darkgreen' if row['SPOT_A1S'] else 'red'
        # Define the icon: check-circle for adopted, info-sign for others
        icon_type = 'check-circle' if row['SPOT_A1S'] else 'info-sign'

        folium.Marker(
            location = [row.geometry.y, row.geometry.x],
            popup = f"Zone: {row['NOM_ZONE']}<br>Date: {row['DATE']}<br>Volume: {row['VOLUME_TOTAL']} litres",
            icon = folium.Icon(color = marker_color, icon = icon_type, prefix = 'fa')
        ).add_to(marker_cluster)

    ##############################
    # 5/ Add the region boundary #
    ##############################

    # Add the region boundary to the map for context
    folium.GeoJson(
        selected_region,
        name = "Region Boundary",
        style_function = lambda feature: {
            'weight': 2,
            'fillOpacity': 0.1,
        }
    ).add_to(m)

    # Return the map
    return m

# %%
# Construct the filter dict
# region = "Occitanie"
# environment = "Littoral (terrestre)"

filter_dict = {"REGION": "Occitanie",
               "TYPE_MILIEU": "Littoral (terrestre)"}

# Test the function
plot_adopted_waste_spots(data_zds,
                         filter_dict)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ef2dc8e186bc6ebc068bd6ef4aeeba0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ef2dc8e186bc6ebc068bd6ef4aeeba0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ef2dc8e186bc6ebc068bd6ef4aeeba0 = L.map(
#                 &quot;map_3ef2dc8e186bc6ebc068bd6ef4aeeba0&quot;,
#                 {
#                     center: [43.11537143095361, 3.578997155789312],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90a57bb958ad90065ab89e1fc8eb52cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_90a57bb958ad90065ab89e1fc8eb52cc.addTo(map_3ef2dc8e186bc6ebc068bd6ef4aeeba0);
#
#
#             var marker_cluster_ff9d078e8e323088603208abced4f912 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_9e4df9bfbe3915aa26a474c93a7f9877 = L.marker(
#                 [43.551909932556, 4.0069316528015],
#                 {}
#             ).addTo(marker_cluster_ff9d078e8e323088603208abced4f912);
#
#
#             var icon_46bb8f4c4a407332089f1a76931c0413 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9e4df9bfbe3915aa26a474c93a7f9877.setIcon(icon_46bb8f4c4a407332089f1a76931c0413);
#
#
#         var popup_6756280ac1028c1facf66d87fce8654f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4954cc9eeecbe9c629b84e93ac302061 = $(`&lt;div id=&quot;html_4954cc9eeecbe9c629b84e93ac302061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zone: Plage du Petit Travers&lt;br&gt;Date: 2019-06-01&lt;br&gt;Volume: 45.0 litres&lt;/div&gt;`)[0];
#                 popup_6756280ac1028c1facf66d87fce8654f.setContent(html_4954cc9eeecbe9c629b84e93ac302061);
#
#
#
#         marker_9e4df9bfbe3915aa26a474c93a7f9877.bindPopup(popup_6756280ac1028c1facf66d87fce8654f)
#         ;
#
#
#
#
#             var marker_153b9b130870eddd3118ff9181074e89 = L.marker(
#                 [43.523961513781, 3.9250100742037],
#                 {}
#             ).addTo(marker_cluster_ff9d078e8e323088603208abced4f912);
#
#
#             var icon_01d33e3aa24daf4fc34cc1b22d3f16a3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_153b9b130870eddd3118ff9181074e89.setIcon(icon_01d33e3aa24daf4fc34cc1b22d3f16a3);
#
#
#         var popup_6b95bde24d7f4fb6888b1a01fa65f69d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b5261d8257bbfafe34ad04b92b8d401 = $(`&lt;div id=&quot;html_9b5261d8257bbfafe34ad04b92b8d401&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zone: Plage Rive droite&lt;br&gt;Date: 2019-09-07&lt;br&gt;Volume: 150.0 litres&lt;/div&gt;`)[0];
#                 popup_6b95bde24d7f4fb6888b1a01fa65f69d.setContent(html_9b5261d8257bbfafe34ad04b92b8d401);
#
#
#
#         marker_153b9b130870eddd3118ff9181074e89.bindPopup(popup_6b95bde24d7f4fb6888b1a01fa65f69d)
#         ;
#
#
#
#
#             var marker_de3a24ef92b9a63a93957f43e0512cb5 = L.marker(
#                 [43.516928412118, 3.9058142438792],
#                 {}
#             ).addTo(marker_cluster_ff9d078e8e323088603208abced4f912);
#
#
#             var icon_89d1754d93ff2a3a18c34e3c490f49e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_de3a24ef92b9a63a93957f43e0512cb5.setIcon(icon_89d1754d93ff2a3a18c34e3c490f49e6);
#
#
#         var popup_90cb0f2157eca87bea2a91ce0cc5b704 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52423af5b842a1eef39ede5960d35930 = $(`&lt;div id=&quot;html_52423af5b842a1eef39ede5960d35930&quot; style=
